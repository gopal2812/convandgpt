# %% [markdown]
# <a href="https://colab.research.google.com/github/gopal2812/convandgpt/blob/main/Submission8/Net_GN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR-10 dataset classification
# ## Net 1

# %% [markdown]
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %% [markdown]
# # Importing basic dependencies

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf /content/convandgpt/
# !git clone https://github.com/gopal2812/convandgpt.git
import os
os.chdir("/content/convandgpt/Submission8")
# !pwd;ls
# Out:
# Cloning into 'convandgpt'...
# remote: Enumerating objects: 165, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (156/156), done.
# remote: Total 165 (delta 75), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (165/165), 709.73 KiB | 5.96 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# /content/convandgpt/Submission8
# dataset.py  model.py  Net_BN.ipynb  transform.py  utils.py  visualize.py

# %%
# del model
import torch
import torch.nn as nn
import torch.optim as optim
from model import Net1
from utils import train, test
import torch.nn.functional as F
from torchsummary import summary

# %%
CLASSES = ("Airplane", "Automobile", "Bird", "Cat", "Deer", "Dog", "Frog", "Horse", "Ship", "Truck")

# %% [markdown]
# Check GPU avaiability

# %%
SEED = 1
torch.manual_seed(1)
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# CUDA?
if device.type == 'cuda':
    torch.cuda.manual_seed(SEED)
else:
    torch.manual_seed(SEED)

# %% [markdown]
# # Model Initialization & Summary

# %%
model = Net1(dropout_percentage=0.05, norm="gn", num_groups=4).to(device)
summary(model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#          GroupNorm-2           [-1, 16, 32, 32]              32
#               ReLU-3           [-1, 16, 32, 32]               0
#            Dropout-4           [-1, 16, 32, 32]               0
#             Conv2d-5           [-1, 32, 32, 32]           4,640
#          GroupNorm-6           [-1, 32, 32, 32]              64
#               ReLU-7           [-1, 32, 32, 32]               0
#            Dropout-8           [-1, 32, 32, 32]               0
#             Conv2d-9           [-1, 16, 32, 32]             528
#         MaxPool2d-10           [-1, 16, 16, 16]               0
#            Conv2d-11           [-1, 16, 16, 16]           2,320
#         GroupNorm-12           [-1, 16, 16, 16]              32
#              ReLU-13           [-1, 16, 16, 16]               0
#           Dropout-14           [-1, 16, 16, 16]               0
#            Conv2d-15           [-1, 32, 16, 16]           4,640
#         GroupNorm-16           [-1, 32, 16, 16]              64
#              ReLU-17           [-1, 32, 16, 16]               0
#           Dropout-18           [-1, 32, 16, 16]               0
#            Conv2d-19           [-1, 32, 16, 16]           9,248
#            Conv2d-20           [-1, 32, 16, 16]             544
#         GroupNorm-21           [-1, 32, 16, 16]              64
#              ReLU-22           [-1, 32, 16, 16]               0
#           Dropout-23           [-1, 32, 16, 16]               0
#            Conv2d-24           [-1, 16, 16, 16]             528
#         MaxPool2d-25             [-1, 16, 8, 8]               0
#            Conv2d-26             [-1, 16, 8, 8]           2,320
#         GroupNorm-27             [-1, 16, 8, 8]              32
#              ReLU-28             [-1, 16, 8, 8]               0
#           Dropout-29             [-1, 16, 8, 8]               0
#            Conv2d-30             [-1, 32, 8, 8]           4,640
#         GroupNorm-31             [-1, 32, 8, 8]              64
#              ReLU-32             [-1, 32, 8, 8]               0
#           Dropout-33             [-1, 32, 8, 8]               0
#            Conv2d-34             [-1, 32, 8, 8]           9,248
#            Conv2d-35             [-1, 32, 8, 8]             544
#         GroupNorm-36             [-1, 32, 8, 8]              64
#              ReLU-37             [-1, 32, 8, 8]               0
#           Dropout-38             [-1, 32, 8, 8]               0
# AdaptiveAvgPool2d-39             [-1, 32, 1, 1]               0
#            Conv2d-40             [-1, 10, 1, 1]             330
# ================================================================
# Total params: 40,394
# Trainable params: 40,394
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.56
# Params size (MB): 0.15
# Estimated Total Size (MB): 2.72
# ----------------------------------------------------------------

# %% [markdown]
# # Dataset & Dataloaders

# %%
from transform import train_transforms, test_transforms

# %%
from dataset import get_dataloaders

batch_size = 64

kwargs = {'batch_size': batch_size, 'shuffle': True, 'num_workers': 4, 'pin_memory': True}
train_loader, test_loader = get_dataloaders(train_transforms=train_transforms, test_transforms=test_transforms, **kwargs)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:01<00:00, 100009683.38it/s]
# Extracting ../data/cifar-10-python.tar.gz to ../data
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# # Data Exploration

# %%
# !pip install torchmetrics
from visualize import plot_data_samples, plot_class_label_counts

# plot_class_label_counts(train_loader, classes=CLASSES)
plot_data_samples(train_loader, classes=CLASSES)
# Out:
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.25.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.0)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.2.1+cu121)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (0.11.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->torchmetrics) (12.4.99)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->torchmetrics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->torchmetrics) (1.3.0)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# # Training

# %%
model = Net1(dropout_percentage=0.02, norm="bn").to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=8, gamma=0.1, verbose=True)
# New Line
criterion = F.nll_loss
num_epochs = 20

# Data to plot accuracy and loss graphs
train_losses = []
test_losses = []
train_acc = []
test_acc = []

for epoch in range(1, num_epochs+1):
  print(f'Epoch {epoch}')
  train_accs, train_losses = train(model, device, train_loader, optimizer, criterion)
  test_accs, test_losses = test(model, device, test_loader, criterion)
  scheduler.step()
# Out:
# Epoch 1
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Train: 100% Loss=1.0886 Batch_id=781 Accuracy=43.60
# Test set: Average loss: 1.2552, Accuracy: 5506/10000 (55.06%)
#
# Epoch 2
# Train: 100% Loss=1.1270 Batch_id=781 Accuracy=59.32
# Test set: Average loss: 1.0249, Accuracy: 6294/10000 (62.94%)
#
# Epoch 3
# Train: 100% Loss=0.6429 Batch_id=781 Accuracy=64.60
# Test set: Average loss: 0.9072, Accuracy: 6706/10000 (67.06%)
#
# Epoch 4
# Train: 100% Loss=1.3382 Batch_id=781 Accuracy=67.45
# Test set: Average loss: 0.9167, Accuracy: 6800/10000 (68.00%)
#
# Epoch 5
# Train: 100% Loss=0.8371 Batch_id=781 Accuracy=69.58
# Test set: Average loss: 0.8971, Accuracy: 6794/10000 (67.94%)
#
# Epoch 6
# Train: 100% Loss=0.7009 Batch_id=781 Accuracy=71.70
# Test set: Average loss: 0.7881, Accuracy: 7262/10000 (72.62%)
#
# Epoch 7
# Train: 100% Loss=1.0187 Batch_id=781 Accuracy=72.83
# Test set: Average loss: 0.7625, Accuracy: 7334/10000 (73.34%)
#
# Epoch 8
# Train: 100% Loss=1.0218 Batch_id=781 Accuracy=73.72
# Test set: Average loss: 0.7497, Accuracy: 7310/10000 (73.10%)
#
# Epoch 9
# Train: 100% Loss=0.8265 Batch_id=781 Accuracy=77.32
# Test set: Average loss: 0.6319, Accuracy: 7750/10000 (77.50%)
#
# Epoch 10
# Train: 100% Loss=0.7132 Batch_id=781 Accuracy=77.80
# Test set: Average loss: 0.6301, Accuracy: 7797/10000 (77.97%)
#
# Epoch 11
# Train: 100% Loss=0.8404 Batch_id=781 Accuracy=78.20
# Test set: Average loss: 0.6186, Accuracy: 7832/10000 (78.32%)
#
# Epoch 12
# Train: 100% Loss=0.6688 Batch_id=781 Accuracy=78.52
# Test set: Average loss: 0.6217, Accuracy: 7832/10000 (78.32%)
#
# Epoch 13
# Train: 100% Loss=0.5255 Batch_id=781 Accuracy=78.65
# Test set: Average loss: 0.6141, Accuracy: 7851/10000 (78.51%)
#
# Epoch 14
# Train: 100% Loss=0.2617 Batch_id=781 Accuracy=78.49
# Test set: Average loss: 0.6183, Accuracy: 7859/10000 (78.59%)
#
# Epoch 15
# Train: 100% Loss=0.6396 Batch_id=781 Accuracy=78.86
# Test set: Average loss: 0.6158, Accuracy: 7842/10000 (78.42%)
#
# Epoch 16
# Train: 100% Loss=0.6715 Batch_id=781 Accuracy=79.24
# Test set: Average loss: 0.6184, Accuracy: 7872/10000 (78.72%)
#
# Epoch 17
# Train: 100% Loss=0.4226 Batch_id=781 Accuracy=79.45
# Test set: Average loss: 0.6016, Accuracy: 7914/10000 (79.14%)
#
# Epoch 18
# Train: 100% Loss=0.9911 Batch_id=781 Accuracy=79.68
# Test set: Average loss: 0.6105, Accuracy: 7872/10000 (78.72%)
#
# Epoch 19
# Train: 100% Loss=0.8012 Batch_id=781 Accuracy=79.59
# Test set: Average loss: 0.6042, Accuracy: 7906/10000 (79.06%)
#
# Epoch 20
# Train: 100% Loss=0.4620 Batch_id=781 Accuracy=79.62
# Test set: Average loss: 0.6009, Accuracy: 7926/10000 (79.26%)

# %%
# !mkdir Store; chmod 777 Store
import pandas as pd
bn_df = pd.DataFrame({'Train Acc': train_accs, 'Test Acc': test_accs, 'Train Loss': train_losses, 'Test Loss': test_losses})
bn_df.to_csv('Store/GN_training.csv', index=False)

# %%
import pandas as pd
bn_train = pd.read_csv("Store/GN_training.csv")
bn_train
train_accs = bn_train['Train Acc'].tolist()
test_accs = bn_train['Test Acc'].tolist()
train_losses = bn_train['Train Loss'].tolist()
test_losses = bn_train['Test Loss'].tolist()

# %%
from visualize import plot_model_training_curves

plot_model_training_curves(train_accs=train_accs, test_accs=test_accs, train_losses=train_losses, test_losses=test_losses)

# %% [markdown]
# # Model Analysis

# %%
from utils import get_all_and_incorrect_preds
from visualize import plot_confusion_matrix

all_preds, all_labels, incorrect = get_all_and_incorrect_preds(model=model, loader=test_loader, device=device)
plot_confusion_matrix(all_labels, all_preds, classes=CLASSES)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
from visualize import plot_incorrect_preds

plot_incorrect_preds(incorrect, classes=CLASSES)
# Out:
# Total Incorrect Predictions 2074

# %%
from google.colab import files
files.download('Store/GN_training.csv')
