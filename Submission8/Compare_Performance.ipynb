# %% [markdown]
# <a href="https://colab.research.google.com/github/gopal2812/convandgpt/blob/main/Submission8/Compare_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0beb99f2-36d1-4d7b-a3dc-506278b9e27a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0beb99f2-36d1-4d7b-a3dc-506278b9e27a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
bn_df = pd.read_csv("/content/BN_training.csv")
ln_df = pd.read_csv("/content/LN_training.csv")
gn_df = pd.read_csv("/content/GN_training.csv")

# %%
bn_df
# Out:
#     Train Acc  Test Acc  Train Loss  Test Loss
# 0      41.236     49.30    1.580688   1.421887
# 1      58.350     63.25    1.159340   1.034664
# 2      63.824     63.91    1.008883   1.017545
# 3      67.288     67.14    0.919347   0.920631
# 4      69.866     71.31    0.852913   0.813257
# 5      71.792     72.23    0.802963   0.795564
# 6      73.262     73.55    0.764886   0.770289
# 7      74.322     75.93    0.733639   0.693953
# 8      77.870     78.34    0.637223   0.627336
# 9      78.322     78.18    0.621149   0.621743
# 10     78.606     78.78    0.616449   0.614100
# 11     78.886     78.91    0.607916   0.614988
# 12     79.166     78.69    0.600162   0.616181
# 13     79.404     79.02    0.591301   0.610916
# 14     79.524     79.00    0.591968   0.611871
# 15     79.404     79.22    0.590965   0.606145
# 16     79.920     79.15    0.579820   0.601267
# 17     80.174     79.57    0.571689   0.595976
# 18     79.886     79.39    0.575566   0.598145
# ...

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 10))
axs[0, 0].plot(bn_df['Train Loss'], label='Batch Norm')
axs[0, 0].set_title("Training Loss")
axs[1, 0].plot(bn_df['Train Acc'], label='Batch Norm')
axs[1, 0].set_title("Training Accuracy")
axs[0, 1].plot(bn_df['Test Loss'], label='Batch Norm')
axs[0, 1].set_title("Test Loss")
axs[1, 1].plot(bn_df['Test Acc'], label='Batch Norm')
axs[1, 1].set_title("Test Accuracy")

axs[0, 0].plot(ln_df['Train Loss'], label='Layer Norm')
axs[1, 0].plot(ln_df['Train Acc'], label='Layer Norm')
axs[0, 1].plot(ln_df['Test Loss'], label='Layer Norm')
axs[1, 1].plot(ln_df['Test Acc'], label='Layer Norm')

axs[0, 0].plot(gn_df['Train Loss'], label='Group Norm')
axs[1, 0].plot(gn_df['Train Acc'], label='Group Norm')
axs[0, 1].plot(gn_df['Test Loss'], label='Group Norm')
axs[1, 1].plot(gn_df['Test Acc'], label='Group Norm')

axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()
plt.plot()
# Out:
# []
